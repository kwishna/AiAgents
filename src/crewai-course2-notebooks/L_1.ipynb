# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

import os
import yaml
from crewai import Agent, Task, Crew

# %%
# requirements file
# note which revision of python, for example 3.9.6
# in this file, insert all the pip install needs, include revision

#### for example:
#### torch==2.0.1
#### matplotlib==3.7.2

#### crewai==0.75
#### crewai_tools==0.12.1

# %%
import sys
import os
from pathlib import Path

project_root = str(Path(os.curdir).resolve().parent.parent)
if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# ## Set OpenAI Model

# %%
import os
from src.utils.util import get_openai_api_key, get_openai_model_name, get_serper_api_key

openai_api_key = get_openai_api_key()
os.environ["OPENAI_MODEL_NAME"] = get_openai_model_name()
os.environ["SERPER_API_KEY"] = get_serper_api_key()

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'l1-configs/agents.yaml',
    'tasks': 'l1-configs/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# %% [markdown]
# ## Crew's Inputs

# %%
# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# 2024-11-17 23:39:58,583 - 140684804464704 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Project Breakdown for Website Development
#
# **Project Overview:**
# The objective is to design and develop a responsive website for a small business that effectively communicates its services while providing a user-friendly experience across devices.
#
# ### Comprehensive Task List
#
# 1. **Create a Responsive Design**
#    - **Description:** Develop a design framework that adapts seamlessly to various screen sizes (desktop, tablet, mobile).
#    - **Duration:** 1 week
#    - **Dependencies:** Completion of visual wireframes.
#    - **Deliverables:** Responsive design mockups.
#
# 2. **Implement a Visually Appealing User Interface**
#    - **Description:** Design and implement a modern UI focusing on color, typography, and layout to create a clean aesthetic.
#    - **Duration:** 2 weeks
#    - **Dependencies:** Completion of responsive design.
#    - **Deliverables:** UI style guide and sample pages.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Description:** Create a clear and intuitive menu structure for easy access to all site pages.
#    - **Duration:** 1 week
#    - **Dependencies:** Finalization of the UI design.
#    - **Deliverables:** Navigation flow diagram and implemented menu.
#
# 4. **Create an "About Us" Page**
#    - **Description:** Write and design the content and layout for the "About Us" page showcasing the company’s history and values.
#    - **Duration:** 1 week
#    - **Dependencies:** Completion of UI design.
#    - **Deliverables:** Completed "About Us" page.
#
# 5. **Design a "Services" Page**
#    - **Description:** Develop a page detailing services offered with descriptions and relevant images.
#    - **Duration:** 1 week
#    - **Dependencies:** "About Us" page approval.
#    - **Deliverables:** Completed "Services" page.
#
# 6. **Create a "Contact Us" Page**
#    - **Description:** Design a page with a contact form and integrated Google map.
#    - **Duration:** 1 week
#    - **Dependencies:** Completion of "Services" page.
#    - **Deliverables:** Completed "Contact Us" page.
#
# 7. **Implement a Blog Section**
#    - **Description:** Develop a blog section for posting articles related to industry news and company updates.
#    - **Duration:** 2 weeks
#    - **Dependencies:** Approval of "Services" page.
#    - **Deliverables:** Functioning blog section.
#
# 8. **Ensure Fast Loading Times and SEO Optimization**
#    - **Description:** Optimize images and code for quick loading times while implementing SEO strategies for visibility.
#    - **Duration:** 2 weeks (concurrent with blog implementation)
#    - **Dependencies:** Completion of all primary pages.
#    - **Deliverables:** SEO report and website performance tests.
#
# 9. **Integrate Social Media Links and Sharing Capabilities**
#    - **Description:** Add social media profiles and sharing options for content.
#    - **Duration:** 1 week
#    - **Dependencies:** Completion of primary pages.
#    - **Deliverables:** Social media integration on all relevant pages.
#
# 10. **Include a Testimonials Section**
#     - **Description:** Design and integrate a section showcasing customer feedback and testimonials to build trust.
#     - **Duration:** 1 week
#     - **Dependencies:** Completion of "Services" page.
#     - **Deliverables:** Live testimonials section.
#
# ### Timeline Visualization (Gantt Chart)
#
# ```
# | Task                                   | Duration       | Start Date    | End Date      |
# |----------------------------------------|----------------|----------------|---------------|
# | Create a Responsive Design             | 1 week         | Week 1        | Week 1        |
# | Implement User Interface                | 2 weeks        | Week 2        | Week 3        |
# | Develop Navigation System              | 1 week         | Week 3        | Week 3        |
# | Create "About Us" Page                | 1 week         | Week 4        | Week 4        |
# | Design "Services" Page                 | 1 week         | Week 5        | Week 5        |
# | Create "Contact Us" Page              | 1 week         | Week 6        | Week 6        |
# | Implement Blog Section                 | 2 weeks        | Week 6        | Week 7        |
# | SEO and Performance Optimization       | 2 weeks        | Week 6        | Week 7        |
# | Integrate Social Media Links           | 1 week         | Week 8        | Week 8        |
# | Include Testimonials Section            | 1 week         | Week 8        | Week 8        |
# ```
#
# ### Project Team Allocation
#
# - **John Doe (Project Manager):** Overall project oversight, timeline management, and ensuring deliverables meet the specified criteria.
# - **Jane Doe (Software Engineer):** Responsible for the development of the navigation system, blog section, and backend functionalities.
# - **Bob Smith (Designer):** Focused on creating the responsive design, UI, and visually appealing component layouts.
# - **Alice Johnson (QA Engineer):** Conducts testing for functionality, user interface, and overall performance.
# - **Tom Brown (QA Engineer):** Specializes in SEO testing and site speed diagnostics.
#
# ### Outcome
# By following this project plan, the intended outcome is a fully functional, visually appealing website that effectively represents the small business, enhances customer engagement, provides information, and facilitates communication, all while ensuring optimal performance both technically and in terms of user experience.
#
# This project is set to achieve completion within 8 weeks, allowing for ample time for testing and adjustments based on feedback.
#
# **End of Final Answer**
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### Project Overview:
# The project aims to design and develop a responsive website for a small business, ensuring user engagement and a seamless experience across all devices.
#
# #### Task Estimations
#
# 1. **Create a Responsive Design**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Designer
#    - **Effort:** 40 hours
#    - **Dependencies:** Completion of visual wireframes.
#    - **Deliverables:** Responsive design mockups.
#    - **Risks:** Potential adjustments required if initial wireframes do not meet project expectations.
#
# 2. **Implement a Visually Appealing User Interface**
#    - **Duration:** 2 weeks
#    - **Resources Required:** 1 Designer, 1 Software Engineer
#    - **Effort:** 80 hours (40 hours for designer, 40 hours for engineer)
#    - **Dependencies:** Completion of responsive design.
#    - **Deliverables:** UI style guide and sample pages.
#    - **Risks:** Changes in design direction leading to additional iterations.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 40 hours
#    - **Dependencies:** Finalization of the UI design.
#    - **Deliverables:** Navigation flow diagram and implemented menu.
#    - **Risks:** Delays if the UI is not finalized on time.
#
# 4. **Create an "About Us" Page**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Designer, 1 Content Writer
#    - **Effort:** 40 hours (20 hours for design, 20 hours for content writing)
#    - **Dependencies:** Completion of UI design.
#    - **Deliverables:** Completed "About Us" page.
#    - **Risks:** The risk of needing multiple revisions based on stakeholder feedback.
#
# 5. **Design a "Services" Page**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Designer, 1 Content Writer
#    - **Effort:** 40 hours (20 hours for design, 20 hours for content writing)
#    - **Dependencies:** "About Us" page approval.
#    - **Deliverables:** Completed "Services" page.
#    - **Risks:** Approval delays causing subsequent tasks to slip.
#
# 6. **Create a "Contact Us" Page**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Designer, 1 Software Engineer
#    - **Effort:** 40 hours (20 hours for design, 20 hours for development)
#    - **Dependencies:** Completion of "Services" page.
#    - **Deliverables:** Completed "Contact Us" page.
#    - **Risks:** Integration issues if Google Maps API changes.
#
# 7. **Implement a Blog Section**
#    - **Duration:** 2 weeks
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 80 hours
#    - **Dependencies:** Approval of "Services" page.
#    - **Deliverables:** Functioning blog section.
#    - **Risks:** Technical difficulties with the CMS integration.
#
# 8. **Ensure Fast Loading Times and SEO Optimization**
#    - **Duration:** 2 weeks (concurrent with blog implementation)
#    - **Resources Required:** 1 Software Engineer, 1 QA Engineer
#    - **Effort:** 80 hours (40 hours for optimization, 40 hours for QA)
#    - **Dependencies:** Completion of all primary pages.
#    - **Deliverables:** SEO report and website performance tests.
#    - **Risks:** Potential for unsatisfactory performance results leading to further adjustments.
#
# 9. **Integrate Social Media Links and Sharing Capabilities**
#    - **Duration:** 1 week
#    - **Resources Required:** 1 Software Engineer
#    - **Effort:** 40 hours
#    - **Dependencies:** Completion of primary pages.
#    - **Deliverables:** Social media integration on all relevant pages.
#    - **Risks:** API changes from social platforms requiring adjustments.
#
# 10. **Include a Testimonials Section**
#     - **Duration:** 1 week
#     - **Resources Required:** 1 Designer, 1 Software Engineer
#     - **Effort:** 40 hours (20 hours for design, 20 hours for integration)
#     - **Dependencies:** Completion of "Services" page.
#     - **Deliverables:** Live testimonials section.
#     - **Risks:** Delay in gathering customer feedback leading to incomplete content.
#
# ### Summary of Risks and Uncertainties
# 1. **Dependency Delays:** Each task is dependent on the completion of the previous one, causing a cascading delay if one task slips.
# 2. **Feedback Variability:** Stakeholder feedback might necessitate additional rounds of revisions, particularly for design-focused tasks.
# 3. **Technical Roadblocks:** Potential issues with third-party API integrations and CMS capabilities may arise, requiring troubleshooting and possibly extending timelines.
# 4. **Resource Availability:** Team members' availability could affect resource allocation if unexpected changes occur.
#
# ---
#
# ### Conclusion
# The project is set to take 8 weeks, accommodating ample time for testing, bug fixing, and stakeholder feedback. The planned methodical approach ensures a comprehensive development cycle, aiming for a successful launch of a functional and responsive website that aligns with the client's expectations. By closely monitoring dependencies and risks, the project team can quickly identify potential obstacles and strategize accordingly to stay on track.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                           | Assigned Team Member(s)          | Start Date | End Date   |
# |------------------------------------------------|----------------------------------|------------|------------|
# | Create a Responsive Design                     | Bob Smith                        | Week 1    | Week 1     |
# | Implement a Visually Appealing User Interface   | Bob Smith & Jane Doe            | Week 2    | Week 3     |
# | Develop User-Friendly Navigation System        | Jane Doe                        | Week 4    | Week 4     |
# | Create an "About Us" Page                      | Bob Smith & Jane Doe            | Week 5    | Week 5     |
# | Design a "Services" Page                       | Bob Smith & Jane Doe            | Week 6    | Week 6     |
# | Create a "Contact Us" Page                     | Bob Smith & Jane Doe            | Week 7    | Week 7     |
# | Implement a Blog Section                       | Jane Doe                        | Week 5    | Week 6     |
# | Ensure Fast Loading Times and SEO Optimization | Jane Doe & Alice Johnson        | Week 8    | Week 9     |
# | Integrate Social Media Links and Sharing Capabilities | Jane Doe                        | Week 8    | Week 8     |
# | Include a Testimonials Section                  | Bob Smith & Jane Doe            | Week 8    | Week 8     |
#
# ### Summary of Rationale Behind Each Allocation Decision:
#
# 1. **Create a Responsive Design**: Assigned to Bob Smith as the sole designer, focusing on the project’s foundational visual elements. This provides clarity and consistency early on.
#
# 2. **Implement a Visually Appealing User Interface**: Both Bob Smith and Jane Doe collaborate on this task. Bob applies design skills while Jane implements the interface, maximizing resource utilization through shared effort.
#
# 3. **Develop User-Friendly Navigation System**: Exclusively assigned to Jane Doe, allowing her to focus on technical execution based on the finalized UI for optimal results.
#
# 4. **Create an "About Us" Page**: A joint effort between Bob Smith and Jane Doe, ensuring both design and content are aligned. This task’s timing follows the UI completion, allowing efficient workflow.
#
# 5. **Design a "Services" Page**: Similarly assigned to Bob Smith and Jane Doe, leveraging their established collaboration and time management to produce design elements smoothly.
#
# 6. **Create a "Contact Us" Page**: Again, Bob Smith and Jane Doe work together, maintaining their efficient partnership while delivering user-friendly interaction elements.
#
# 7. **Implement a Blog Section**: Assigned to Jane Doe, as her workload can accommodate this development task during the about/services page creation phase to prevent delays through overlapping skills.
#
# 8. **Ensure Fast Loading Times and SEO Optimization**: Collaborative effort of Jane Doe and Alice Johnson allows for design validation from a QA perspective, ensuring quality while enhancing site performance.
#
# 9. **Integrate Social Media Links and Sharing Capabilities**: Assigned to Jane Doe due to her expertise, optimizing the social elements across the completed pages to leverage previous knowledge and ease integration.
#
# 10. **Include a Testimonials Section**: Assigned to both Bob Smith and Jane Doe, balancing between design requirements and development efforts to finalize user engagement features by project end.
#
# ### Conclusion:
# This strategic allocation utilizes each team member’s expertise while ensuring smooth dependencies and timelines across the project. The overlap in tasks ensures that workload is balanced without overwhelming any individual, fostering a collaborative team atmosphere and thereby enhancing project success. By closely monitoring dependencies and adapting to any resource availability changes, the project can maintain momentum and adapt quickly to potential challenges.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0026
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         17540          10803               6737                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement a Visually Appealing User Interface',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 15.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': "Create an 'About Us' Page",
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': "Design a 'Services' Page",
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': "Create a 'Contact Us' Page",
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Implement a Blog Section',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Ensure Fast Loading Times and SEO Optimization',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson']},
#   {'task_name': 'Integrate Social Media Links and Sharing Capabilities',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include a Testimonials Section',
#    'estimated_time_hours': 10.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']}],
#  'milestones': [{'milestone_name': 'Website Design Completion',
#    'tasks': ['Create a Responsive Design',
#     'Implement a Visually Appealing User Interface',
#     'Develop User-Friendly Navigation System']},
#   {'milestone_name': 'Content and Page Creation',
#    'tasks': ["Create an 'About Us' Page",
#     "Design a 'Services' Page",
#     "Create a 'Contact Us' Page",
#     'Implement a Blog Section']},
#   {'milestone_name': 'SEO and Optimization',
#    'tasks': ['Ensure Fast Loading Times and SEO Optimization',
#     'Integrate Social Media Links and Sharing Capabilities',
#     'Include a Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_11f97 th {
#   font-size: 120%;
# }
# #T_11f97  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_11f97" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11f97_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_11f97_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_11f97_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11f97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11f97_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_11f97_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_11f97_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11f97_row1_col0" class="data row1 col0" >Implement a Visually Appealing User Interface</td>
#       <td id="T_11f97_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_11f97_row1_col2" class="data row1 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11f97_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_11f97_row2_col1" class="data row2 col1" >15.000000</td>
#       <td id="T_11f97_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11f97_row3_col0" class="data row3 col0" >Create an 'About Us' Page</td>
#       <td id="T_11f97_row3_col1" class="data row3 col1" >10.000000</td>
#       <td id="T_11f97_row3_col2" class="data row3 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11f97_row4_col0" class="data row4 col0" >Design a 'Services' Page</td>
#       <td id="T_11f97_row4_col1" class="data row4 col1" >10.000000</td>
#       <td id="T_11f97_row4_col2" class="data row4 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11f97_row5_col0" class="data row5 col0" >Create a 'Contact Us' Page</td>
#       <td id="T_11f97_row5_col1" class="data row5 col1" >10.000000</td>
#       <td id="T_11f97_row5_col2" class="data row5 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11f97_row6_col0" class="data row6 col0" >Implement a Blog Section</td>
#       <td id="T_11f97_row6_col1" class="data row6 col1" >20.000000</td>
#       <td id="T_11f97_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11f97_row7_col0" class="data row7 col0" >Ensure Fast Loading Times and SEO Optimization</td>
#       <td id="T_11f97_row7_col1" class="data row7 col1" >25.000000</td>
#       <td id="T_11f97_row7_col2" class="data row7 col2" >['Jane Doe', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11f97_row8_col0" class="data row8 col0" >Integrate Social Media Links and Sharing Capabilities</td>
#       <td id="T_11f97_row8_col1" class="data row8 col1" >10.000000</td>
#       <td id="T_11f97_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_11f97_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11f97_row9_col0" class="data row9 col0" >Include a Testimonials Section</td>
#       <td id="T_11f97_row9_col1" class="data row9 col1" >10.000000</td>
#       <td id="T_11f97_row9_col2" class="data row9 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_2b51a th {
#   font-size: 120%;
# }
# #T_2b51a  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_2b51a" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b51a_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_2b51a_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b51a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b51a_row0_col0" class="data row0 col0" >Website Design Completion</td>
#       <td id="T_2b51a_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement a Visually Appealing User Interface', 'Develop User-Friendly Navigation System']</td>
#     </tr>
#     <tr>
#       <th id="T_2b51a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b51a_row1_col0" class="data row1 col0" >Content and Page Creation</td>
#       <td id="T_2b51a_row1_col1" class="data row1 col1" >["Create an 'About Us' Page", "Design a 'Services' Page", "Create a 'Contact Us' Page", 'Implement a Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_2b51a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b51a_row2_col0" class="data row2 col0" >SEO and Optimization</td>
#       <td id="T_2b51a_row2_col1" class="data row2 col1" >['Ensure Fast Loading Times and SEO Optimization', 'Integrate Social Media Links and Sharing Capabilities', 'Include a Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
